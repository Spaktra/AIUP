# %%
"""
scipy.linalg
scipy.special
scipy.integrate
scipy.optimize
scipy.interpolate
scipy.fftpack
scipy.signal
scipy.sparse.csgraph
scipy.spatial
scipy.stats
scipy.ndimage
scipy.io
"""
# Out:
# '\nscipy.linalg\nscipy.special\nscipy.integrate\nscipy.optimize\nscipy.interpolate\nscipy.fftpack\nscipy.signal\nscipy.sparse.csgraph\nscipy.spatial\nscipy.stats\nscipy.ndimage\nscipy.io\n'

# %%
import scipy as sp

# %%
import numpy as np
from scipy import linalg

A = np.array([[1,2],[3,4]])
print(A)
B = linalg.inv(A)
print(B)
# Out:
# [[1 2]
#  [3 4]]
# [[-2.   1. ]
#  [ 1.5 -0.5]]

# %%
b = np.array([[5,6],[7,8],[9,10]])
print(b)
print(b.T)
# Out:
# [[ 5  6]
#  [ 7  8]
#  [ 9 10]]
# [[ 5  7  9]
#  [ 6  8 10]]

# %%
#Denklem Takımlarının Çözümü
A = np.array([[1,3,5],[2,5,1],[2,3,8]])
print(A)
b = np.array([[10],[8],[3]])
print(b)
print("\n 1- scipy çözümü :")
print(linalg.inv(A).dot(b)) #Yavaş çözüm
print("\n 2- numpy solve çözümü :")
print(np.linalg.solve(A, b)) #Hızlı çözüm
# Out:
# [[1 3 5]
#  [2 5 1]
#  [2 3 8]]
# [[10]
#  [ 8]
#  [ 3]]
#
#  1- scipy çözümü :
# [[-9.28]
#  [ 5.16]
#  [ 0.76]]
#
#  2- numpy solve çözümü :
# [[-9.28]
#  [ 5.16]
#  [ 0.76]]

# %%
#İntegral 
from scipy import integrate

x2 = lambda x : x**2
I = integrate.quad(x2, 0, 6)
print(I)
# Out:
# (72.00000000000001, 7.993605777301129e-13)

# %%
import scipy.integrate as integrate
import scipy.special as special
result = integrate.quad(lambda x: special.jv(2.5, x), 0, 4.5)
print(result)
# Out:
# (1.1178179380783244, 7.866317216380707e-09)

# %%
from scipy.misc import derivative
def f(x):
    return x**3 + x**2

D = derivative(f, 1.0, dx = 1e-6)
print(D)
# Out:
# 4.999999999921734

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.style.use('seaborn-darkgrid')

# %%
#Çizli (Line) Grafikleri

x = np.array([1,2,3,4,5,6])
y = np.power(x, 3)
plt.plot(x,y)
plt.show()

# %%
x = np.linspace(0, 10, 1000)
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %%
mpl.rcParams.update(mpl.rcParamsDefault) # Temayı sıfırlama

# %%
x = np.linspace(0, 10, 1000)
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %%
plt.style.use('seaborn-darkgrid')
# %matplotlib inline

# %%
plt.figure(figsize = (10,5))
x = np.linspace(0, 10, 1000)
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %%
plt.figure(figsize = (10,5))
x = np.linspace(0, 10, 1000)
y = np.sin(x)
plt.plot(x, y, 'b-')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %%
plt.figure(figsize = (10,5))
x = np.linspace(0, 10, 1000)
y = np.sin(x)
plt.plot(x, y, 'r-')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %%
plt.figure(figsize = (10,5))
x = np.linspace(0, 10, 40)
y = np.sin(x)
plt.plot(x, y, 'go')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %%
plt.figure(figsize = (10,5))
x = np.linspace(0, 10, 40)
y = np.sin(x)
plt.plot(x, y, 'ro')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %%
plt.figure(figsize = (10,5))
x = np.linspace(0, 10, 40)
y = np.sin(x)
plt.plot(x, y, 'r^')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %%
plt.figure(figsize = (10,5))
x = np.linspace(0, 10, 40)
y = np.sin(x)
plt.plot(x, y, 'rv')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %%
plt.figure(figsize = (10,5))
x = np.array([1,2,3,4,5,6])
y1 = np.power(x, 2)
y2 = np.power(x, 3)
plt.plot(x, y1, 'b-', label = '$y1 = x^2$')
plt.plot(x, y2, 'r-', label = '$y2 = x^3$')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (10,5))
x = np.array([1,2,3,4,5,6])
y1 = np.power(x, 2)
y2 = np.power(x, 3)
plt.plot(x, y1, 'b-', label = '$y1 = x^2$')
plt.plot(x, y2, 'r-', label = '$y2 = x^3$')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.legend(loc = "upper center", fontsize = 'large')
plt.show()

# %%
x = np.linspace(0, 10, 2000)
plt.figure(figsize = (10,6))
plt.plot(x, np.sin(x), label = '$sin(x)$')
plt.plot(x, np.cos(x), label = '$cos(x)$')
plt.xlabel(r'$x$', fontsize = 18)
plt.ylabel(r'$y$', fontsize = 18)
plt.title('$sin(x) $ $ & $ $ cos(x)$', fontsize = 14)
plt.legend(loc = 'upper right')
plt.show()

# %%
x = np.linspace(0, 10, 2000)
plt.figure(figsize = (10,6))
plt.plot(x, np.sin(x), label = '$sin(x)$')
plt.plot(x, np.cos(x), label = '$cos(x)$')
plt.fill_between(x, 0, np.sin(x))
plt.fill_between(x, 0, np.cos(x))
plt.xlabel(r'$x$', fontsize = 18)
plt.ylabel(r'$y$', fontsize = 18)
plt.title('$sin(x) $ $ & $ $ cos(x)$', fontsize = 14)
plt.legend(loc = 'lower left')
plt.show()

# %%
plt.figure(figsize = (14,6))
x = np.linspace(0,10,100)
y1 = np.sin(x)
y2 = np.cos(x)
plt.subplot(1,2,1)
plt.plot(x, y1)
plt.subplot(1,2,2)
plt.plot(x, y2)
plt.show()

# %%
plt.figure(figsize = (12,6))
x = np.linspace(0,10,100)
y1 = np.sin(x)
y2 = np.cos(x)

plt.subplot(2,1,1)
plt.plot(x, y1, 'b-')

plt.subplot(2,1,2)
plt.plot(x, y2, 'r-')
plt.tight_layout()
plt.show()

# %%
x = np.arange(-50, 50)
y1 = np.power(x, 2)
y2 = np.tan(x)
y3 = np.exp(x)
y4 = np.power(x,3)

fig1, ax1 = plt.subplots(nrows = 2, ncols = 2, figsize = (12,12))
ax1[0,0].plot(x, y1, 'tab:blue')
ax1[0,0].set_title("Square function") 
ax1[0,0].set_xlabel(r'$x$', fontsize = 18)
ax1[0,0].set_ylabel(r'$y$', fontsize = 18)

ax1[0,1].plot(x, y2, 'r-')
ax1[0,1].set_title("Tangent function") 
ax1[0,1].set_xlabel(r'$x$', fontsize = 18)
ax1[0,1].set_ylabel(r'$y$', fontsize = 18)

ax1[1,0].plot(x, y3, 'k-')
ax1[1,0].set_title("Exponantial function") 
ax1[1,0].set_xlabel(r'$x$', fontsize = 18)
ax1[1,0].set_ylabel(r'$y$', fontsize = 18)

ax1[1,1].plot(x, y4, 'tab:orange')
ax1[1,1].set_title("Cubic function") 
ax1[1,1].set_xlabel(r'$x$', fontsize = 18)
ax1[1,1].set_ylabel(r'$y$', fontsize = 18)
plt.show()

# %%
#Çubuk Grafiği

# %%
id1 = np.arange(1,10)
score = np.arange(20,110,10)
plt.bar(id1, score)
plt.xlabel('Student ID')
plt.ylabel('Score')
plt.show()

# %%
id1 = np.arange(1,10)
score = np.arange(20,110,10)
ax =plt.axes()
ax.set_facecolor('#ECF0F1') # arkaplanın rengini değiştirir
plt.bar(id1, score, color = '#FFA726')
plt.xlabel(r'$Student $ $ID$')
plt.ylabel(r'$Score$')
plt.show()

# %%
x1 = [1,3,5,7]
x2 = [2,4,6,8]
y1 = [7,7,7,7]
y2 = [17,18,29,40]

plt.figure(figsize = (8,6))
ax = plt.axes()
ax.set_facecolor('white')

plt.bar(x1, y1, label = 'First', color = '#42B300')
plt.bar(x2, y2, label = 'Seconda', color = '#94E413')
plt.xlabel('$X$')
plt.ylabel('$Y$')
plt.title('$Bar $  $ Char$')
plt.legend()
plt.show()

# %%
Age = [28, 33, 43, 45, 57]
Name = ['Ahmet', 'Aleyna', 'Ali', 'Berkan', 'Berkay']
plt.barh(Name, Age, color = 'yellowgreen')
plt.show()

# %%
num1 = np.array([1,3,5,7,9])
num2 = np.array([2,4,6,8,10])
plt.figure(figsize = (8,4))
plt.bar(num1, num1**2, width = 0.2, color = '#FF6F00')
plt.bar(num2, num2**2, width = 0.2, color = '#FFB300')
plt.plot()
plt.show()

# %%
x1 = ['Burak', 'Deniz', 'Egenur', 'Esra']
y1 = np.array([17,18,29,40])
y2 = np.array([20,21,22,23])
y3 = np.array([5,9,11,12])
plt.figure(figsize = (5,7))
plt.bar(x1, y1, label = 'Satışa Açık Biletler',width = 0.5, color = '#FF6F00')
plt.bar(x1, y2, label = 'Satışa Kapalı Biletler',width = 0.5, bottom = y1, color = '#FFB300')
plt.bar(x1, y3, label = 'İptal Edilen Biletler',width = 0.5, bottom = y1+y2, color = '#F7DC6F')
plt.xlabel('$X$')
plt.ylabel('$Y$')
plt.title('$Bar $  $ Char$')
plt.legend()
plt.show()

# %%
#ÜSTTEKİ GRAFİĞİ HORIZONTAL YAPMAYI DENE !!!!!
#BARLARA DEĞER YAZMAYI ARAŞTIR (plt.text(x, y, '%d', %y, ha, va)) !!!!!

# %%
#Scatter (Saçılım) Grafikleri

# %%
x1 = np.array([250,150,350,252,450,550,455,358,158,355])
y1 = np.array([40,50,80,90,100,50,60,88,54,45])

plt.scatter(x1, y1)
plt.xlabel('$Time $ $ Spent $', fontsize=12)
plt.ylabel('$Score$', fontsize = 12)
plt.title('Scatter Graph')
plt.show()
